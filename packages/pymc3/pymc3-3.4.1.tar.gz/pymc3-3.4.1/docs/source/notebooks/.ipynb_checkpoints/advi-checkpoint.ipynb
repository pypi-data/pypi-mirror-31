# %%
# %pylab inline
import numpy as np
from scipy import stats
import pymc3 as pm
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.random.randn(100)

# %%
with pm.Model() as model: 
    mu = pm.Normal('mu', mu=0, sd=1, testval=0)
    sd = pm.HalfNormal('sd', sd=1)
    n = pm.Normal('n', mu=mu, sd=sd, observed=data)

# %%
means, sds, elbos = pm.variational.advi(model=model, n=20000, accurate_elbo=True, tol_obj=0.001)
# Out:
# Average ELBO = -142.79:  49%|████▉     | 9783/20000 [00:23<00:25, 408.53it/s]Median ELBO converged.
# Finished [100%]: Average ELBO = -142.12

# %%
with model:
    step = pm.NUTS()
    trace = pm.sample(1000, step)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#  13%|█▎        | 134/1000 [00:00<00:00, 1336.99it/s]
#  32%|███▏      | 319/1000 [00:00<00:00, 1458.01it/s]
#  55%|█████▌    | 553/1000 [00:00<00:00, 1643.74it/s]
#  75%|███████▌  | 754/1000 [00:00<00:00, 1737.78it/s]
#  97%|█████████▋| 971/1000 [00:00<00:00, 1847.41it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1917.82it/s]

# %%
print(trace['mu'].mean())
print(trace['sd_log_'].mean())
print(trace['mu'].std())
print(trace['sd_log_'].std())
# Out:
# -0.105863633802
# -0.0336603755252
# 0.0970513980035
# 0.0702399897654

# %%
ax = sns.distplot(trace['mu'], label='NUTS')
xlim = ax.get_xlim()
x = np.linspace(xlim[0], xlim[1], 100)
y = stats.norm(means['mu'], sds['mu']).pdf(x)
ax.plot(x, y, label='ADVI')
ax.set_title('mu')
ax.legend(loc=0)

# %%
ax = sns.distplot(trace['sd_log_'], label='NUTS')
xlim = ax.get_xlim()
x = np.linspace(xlim[0], xlim[1], 100)
y = stats.norm(means['sd_log_'], sds['sd_log_']).pdf(x)
ax.plot(x, y, label='ADVI')
ax.set_title('log(sigma)')
ax.legend(loc=0)

# %%
import matplotlib.pyplot as plt
plt.plot(elbos[5000:])
# Out:
# Average ELBO = -142.79:  49%|████▉     | 9783/20000 [00:40<00:41, 243.63it/s]
